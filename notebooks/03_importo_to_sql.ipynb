# %%
import pandas as pd

df = pd.read_csv("../data/processed/feature_engineered_loans.csv")

# %%
df.shape
# Out:
# (1344690, 23)

# %%
df.head()
# Out:
#    loan_amnt        term  int_rate grade sub_grade  emp_length home_ownership  \
# 0     3600.0   36 months     13.99     C        C4        10.0       MORTGAGE
# 1    24700.0   36 months     11.99     C        C1        10.0       MORTGAGE
# 2    20000.0   60 months     10.78     B        B4        10.0       MORTGAGE
# 3    10400.0   60 months     22.45     F        F1         3.0       MORTGAGE
# 4    11950.0   36 months     13.44     C        C3         4.0           RENT
#
#    annual_inc verification_status loan_status  ... fico_range_low  \
# 0     55000.0        Not Verified  Fully Paid  ...          675.0
# 1     65000.0        Not Verified  Fully Paid  ...          715.0
# 2     63000.0        Not Verified  Fully Paid  ...          695.0
# 3    104433.0     Source Verified  Fully Paid  ...          695.0
# 4     34000.0     Source Verified  Fully Paid  ...          690.0
#
#   fico_range_high  installment  is_default  loan_to_income  monthly_income  \
# ...

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "mssql+pyodbc://@DESKTOP-RSV486C\\SQLEXPRESS/LoanAnalysis?driver=ODBC+Driver+17+for+SQL+Server&trusted_connection=yes"
)

# %%
engine.connect()

# %%
df.to_sql(
    "loans",
    engine,
    if_exists="append",
    index=False,
    chunksize=5000
)
# Out:
# 23097
